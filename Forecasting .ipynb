# %% [markdown]
# #1
# This analysis is done using Pandas module of Python, first data is read from the  dataset using pandas.read_excel() after that all the analysis question are answered using, # 3re question is to add a column for the change in the price, i have used a python function to calculate the percent change for each data in the dataset.xls file and added that to the dataset.The 5 insight observations are
# Cruid oil costs more than rest of all the fule.
# Propane is the  cheapest of all
# The price of the oils increase with very small amount every month
# But to almost all the mont there is an change.
# Price data of only some citys are there for certain type of oil.
# For the Deisel fule the maximum data is provided to us.

# %% [markdown]
# #2
# According to my observation, the external factor wich affects the most to increase in price of the  peterolium products are environment condition. And also the Demand and supply matters. i.e. if there is more demand of the petrolium product and the supply is less then definetily there is rise in the price  of the petrolium products, and if there is less demand than the prise of the petrolium products will decrese. Rest of all the factors which affacts the petrolium price are dependent on the demand and supply.

# %%
#3.Create column to find price changes month over month 
import pandas as pd
# for i in range(1, 8):
#     x = pd.read_excel('dataset.xls', sheetname=i)
x = pd.read_excel('dataset.xls', sheetname=1)
# x
x['Change'] = x['Data 1: Crude Oil'][2:].pct_change(periods=1, fill_method='pad')
# x
# Out:
# c:\users\anand\appdata\local\programs\python\python36\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
import pandas as pd
x1 = pd.read_excel('dataset.xls', sheetname=2)
x1['Change(New York)'] = x1['Data 2: Conventional Gasoline'][2:].pct_change(periods=1, fill_method='pad')
x1['Change(U.S)'] = x1['Unnamed: 2'][2:].pct_change(periods=1, fill_method='pad')
# x1

# %%
# 3.Create column to find price changes month over month 
import pandas as pd
x2 = pd.read_excel('dataset.xls', sheetname=3)
x2['Change'] = x2['Data 3: RBOB Regular Gasoline'][2:].pct_change(periods=1, fill_method='pad')
# x2

# %%
# 3.Create column to find price changes month over month 
import pandas as pd
x3 = pd.read_excel('dataset.xls', sheetname=4)
x3['Change'] = x3['Data 4: No. 2 Heating Oil'][2:].pct_change(periods=1, fill_method='pad')
# x3

# %%
#3.Create column to find price changes month over month  
import pandas as pd
x4 = pd.read_excel('dataset.xls', sheetname=5)
x4['Change(N.Y)'] = x4['Data 5: Ultra-Low-Sulfur No. 2 Diesel Fuel'][2:].pct_change(periods=1, fill_method='pad')
x4['Change(U.S)'] = x4['Unnamed: 2'][2:].pct_change(periods=1, fill_method='pad')
x4['Change(L.A)'] = x4['Unnamed: 3'][2:].pct_change(periods=1, fill_method='pad')
# x4

# %%
#3.Create column to find price changes month over month  
import pandas as pd
x5 = pd.read_excel('dataset.xls', sheetname=6)
x5['Change'] = x5['Data 6: Kerosene-Type Jet Fuel'][2:].pct_change(periods=1, fill_method='pad')
# x5

# %%
# 3.Create column to find price changes month over month 
import pandas as pd
x6 = pd.read_excel('dataset.xls', sheetname=7)
x6['Change'] = x6['Data 7: Propane'][2:].pct_change(periods=1, fill_method='pad')
# x6

# %%
#4. Create a summarized price and price movement.
y = pd.read_excel('dataset.xls')
y.describe(include='all')
# Out:
#         Unnamed: 0                               Workbook Contents Unnamed: 2  \
# count          0.0                                              16         14
# unique         NaN                                              16         14
# top            NaN  Click worksheet name or tab at bottom for data    Propane
# freq           NaN                                               1          1
# mean           NaN                                             NaN        NaN
# std            NaN                                             NaN        NaN
# min            NaN                                             NaN        NaN
# 25%            NaN                                             NaN        NaN
# 50%            NaN                                             NaN        NaN
# 75%            NaN                                             NaN        NaN
# max            NaN                                             NaN        NaN
#
#         Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# count          8.0          8          9          7
# unique         4.0          2          3          6
# top            1.0    Monthly     1/2019  6/15/1986
# freq           4.0          7          7          2
# mean           NaN        NaN        NaN        NaN
# std            NaN        NaN        NaN        NaN
# min            NaN        NaN        NaN        NaN
# 25%            NaN        NaN        NaN        NaN
# 50%            NaN        NaN        NaN        NaN
# 75%            NaN        NaN        NaN        NaN
# max            NaN        NaN        NaN        NaN

# %%
#another way of describing
#4. Create a summarized price and price movement by year
import pandas_profiling
pandas_profiling.ProfileReport(x1)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>394 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.2% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>15.5 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>40.2 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>3 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Back to Contents"><code>Back to Contents</code></a> is an unsupported type, check if it needs cleaning or further analysis <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Change(U.S)"><code>Change(U.S)</code></a> is highly correlated with <a href="#pp_var_Change(New York)"><code>Change(New York)</code></a> (ρ = 0.95257) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Data 2: Conventional Gasoline"><code>Data 2: Conventional Gasoline</code></a> is an unsupported type, check if it needs cleaning or further analysis <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Unnamed: 2"><code>Unnamed: 2</code></a> is an unsupported type, check if it needs cleaning or further analysis <span class="label label-warning">Warning</span></li><li>Dataset has 2 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow ignore">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Back to Contents"><s>Back to Contents</s><br/>
#             <small>Unsupported</small>

# %%
#5. Predict the crude oil price for next 6 months
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import mean_squared_error

# Setup paths for the input data
path = "dataset.xls"
# Path to save the test results of predicted next 6 months prices
test_path = "testResults.csv"

#Array of Dataframes input
data = []

for i in range(8):
    if(i!=0):
        data.append(pd.read_excel(path, sheetname = i, skiprows = [0,1]))

#result storing average value and price change per year
resultdf = []

#result storing average value and price change per year
resultdf_monthly = []

#Types of Data Available
types = ['Crude Oil', 'Conventional Gasoline', 'RBOB Regular Gasoline', 'Heating Oil', 'Diesel Fuel', 'Kerosene Type Jet Fuel', 'Propane']


#### This method applies the initial analysis of Finding Monthly and Yearly Change in Price
def analyze(data2, ind):
    monthList = []
    yearList = []
    monthDiff = []
    nextData = []
    row_iterator = data2.iterrows()
    
    str_cols = data2.columns[data2.dtypes==object]
    data2[str_cols] = data2[str_cols].fillna('.')
    data2.fillna(0,inplace=True)
    
    for index, row in row_iterator:
        current_date = row['Date'] 
        monthList.append(current_date.month)
        yearList.append(current_date.year)
        if(index == len(data2)-1):
            nextData.append(data2.iloc[index][1])
            monthDiff.append(0)
        else:
            nextData.append(data2.iloc[index+1][1])
            monthDiff.append(data2.iloc[index+1][1] - row[1])
    
    data2['Month'] = monthList
    data2['Year'] = yearList
    data2['Monthly Change in Price'] = monthDiff     
        
           
    #generate map from keys
    map_month = dict.fromkeys(data2.Month.unique())
    
    for month in data2.Month.unique():
        df1 = data2.loc[data2['Month'] == month]
        print('*******')
        print('For month', month)
        print(df1.iloc[:,1])
        mean_mnth = np.asarray(df1.iloc[:,1]).mean()
        print('mean:',mean_mnth )
        map_month[month] = mean_mnth
    
    yearls_m = list(map_month.keys())
    print(map_month)

    meanls_m = list(map_month.values())
    
    res = pd.DataFrame(np.column_stack([yearls_m, meanls_m]), 
                               columns=['Month', 'Mean Price of '+str(types[ind])])

    resultdf_monthly.append(res) 

    
    #generate map from keys
    map_ = dict.fromkeys(data2.Year.unique())
    
    
    for yr in data2.Year.unique():
        df = data2.loc[data2['Year'] == yr]
        mean = np.asarray(df.iloc[:,1]).mean()
        map_[yr] = mean
    
    yearls = list(map_.keys())

    meanls = list(map_.values())
    
    result = pd.DataFrame(np.column_stack([yearls, meanls]), 
                               columns=['Year', 'Mean Price of '+str(types[ind])])
    
    yearDiff = []
    for index, row in result.iterrows():
        if(index == len(result)-1):
            yearDiff.append(0)
        else:
            yearDiff.append(result.iloc[index+1][1] - row[1])
    
    result['Yearly Change in Price'] = yearDiff 
    
    resultdf.append(result) 


### Method where different machine learning models are trained and comparitive study is done
def trainModels(file, imp_attr):
    #split into train and test
    train, test =  train_test_split(file, test_size = 0.2)

    #Removing the target/predictor from the train data
    targ = train[list(target_col)]
    
    ### Random Forest Model
    rand_forest_model =  RandomForestRegressor(n_estimators = 1000 , max_features = 2, oob_score = True ,  random_state = 115)
    rand_forest_model.fit(train[list(imp_attr)],targ)
    
    ### Decision Tree Model
    decision_tree_model = DecisionTreeRegressor(max_depth=4)
    decision_tree_model.fit(train[list(imp_attr)],targ)    
   
    ### Linear Regression Model
    linear_model = LinearRegression()
    linear_model.fit(train[list(imp_attr)], targ)
    
    return rand_forest_model, decision_tree_model, linear_model, test

#### Method which tests the given model and Prints out the statistics regarding each of them
def  testNEvalModels(test, rf_model, dt_model, lm_model, imp_attr):
   
    print('\n Evaluation Staistics:')
    ### Evaluating Random Forest
    print("\n ***Random Forest Regressor***")
    #Evaluation metric: r square
    r2 = r2_score(test[list(target_col)] , rf_model.predict(test[list(imp_attr)]))
    print("R-Square Value:", r2)
    
    # extracting the test target values and convert to float
    true_vals = test[list(target_col)].values
    true_vals_flt = true_vals.astype(np.float)
    
    prediction = rf_model.predict(test[list(imp_attr)])
    
    #reshaping the array is required to convert it into numpy array
    aa = prediction.reshape(-1,1)
    
    mean_squared_error(true_vals_flt, prediction)
    
    mse = np.mean((true_vals_flt - aa)**2)
    print("Mean Squared Error", mse)
    
    print("Explained Variance Score", explained_variance_score(true_vals_flt, prediction))     
    print("Mean Absolute Error", mean_absolute_error(true_vals_flt, prediction))
    print("Median Absolute Error", median_absolute_error(true_vals_flt, prediction))    
    
    ### Evaluating Decision tree
    print("\n ***Decision Tree Regressor***")
    y_2 = dt_model.predict(test[list(imp_attr)])
    r2_dt = r2_score(true_vals_flt , y_2)
    print("R-Square Value:", r2_dt)
    
    print("Mean Squared Error", mean_squared_error(true_vals_flt, y_2))  
    
    print("Explained Variance Score", explained_variance_score(true_vals_flt, y_2))     
    print("Mean Absolute Error", mean_absolute_error(true_vals_flt, y_2))
    print("Median Absolute Error", median_absolute_error(true_vals_flt, y_2))    
    
    
    ### Evaluating Linear Model
    print("\n ***Linear Regression Model***")
    pred_lm = lm_model.predict(test[list(imp_attr)])

    r2_lm = r2_score(true_vals_flt, pred_lm)
    
    print("R-Square Value:", r2_lm)
    
    print("Mean Squared Error", mean_squared_error(true_vals_flt, pred_lm))  
    
    print("Explained Variance Score", explained_variance_score(true_vals_flt, pred_lm))     
    print("Mean Absolute Error", mean_absolute_error(true_vals_flt, pred_lm))
    print("Median Absolute Error", median_absolute_error(true_vals_flt, pred_lm))    


#### The chosen model is then applied to predict the future crude oil prices
def applyModel(model, test):
    #Apply selected model to test data
    pred = model.predict(test[list(imp_attr)])

    #save predicted into target column in test
    test_dtm['Predicted Price'] = pred
    
    #save df to file
    test_dtm.to_csv(test_path)


# Create a Excel Writer Object to Write Yearly analysis Price Change
writer = pd.ExcelWriter('output.xlsx')
writer_m = pd.ExcelWriter('output_m.xlsx')

for i in range(len(data)):
    analyze(data[i], i)

#Storing resultant yearly analysis
for i in range(len(resultdf)):
    resultdf[i].to_excel(writer,'data'+str(i))
writer.save()

#Storing resultant yearly analysis
for i in range(len(resultdf_monthly)):
    resultdf_monthly[i].to_excel(writer_m,'data'+str(i))
writer_m.save()


##### Code to predict the next 6 months Prices 

#Crude oil data being taken as input
train_data = data[0]
target_col = ["Cushing, OK WTI Spot Price FOB (Dollars per Barrel)"]

#features selected on which the model would be based on
imp_attr = ['Month','Year']

# Training different models and choosing the best one for prediction
rf,dt,lm,test = trainModels(train_data, imp_attr)
testNEvalModels(test, rf, dt, lm, imp_attr)

#create test data for next 6 months
test_dtm={}
test_dtm['Month']=[5,6,7,8,9,10]
test_dtm['Year']=[2017, 2017, 2017, 2017, 2017, 2017]
test_dtm = pd.DataFrame.from_dict(test_dtm)

# As per the Evaluation Statistics we get to know that Random Forest 
# is performing better than other considered models, so we apply rf to test data
applyModel(rf, test_dtm)

print("Yearly Change in Price is stored in file named: output.xlsx")
print("Monthly Change in Price is stored in file named: output_m.xlsx")
print("The resultant Predicted Values are stored in a File named: testResults.csv")
# Out:
# c:\users\kaush\appdata\local\programs\python\python36\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# *******
# For month 1
# 0       22.93
# 12      18.65
# 24      17.13
# 36      18.02
# 48      22.86
# 60      25.23
# 72      18.79
# 84      19.03
# 96      15.03
# 108     18.04
# 120     18.86
# 132     25.13
# 144     16.72
# 156     12.52
# 168     27.26
# 180     29.59
# 192     19.72
# 204     32.95
# 216     34.31
# 228     46.84
# 240     65.49
# 252     54.51
# 264     92.97
# 276     41.71
# 288     78.33
# 300     89.17
# 312    100.27
# 324     94.76
# 336     94.62
# 348     47.22
# 360     31.68
# 372     52.50
# 384     63.70
# 396     51.38
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 41.703529411764706
# *******
# For month 2
# 1       15.46
# 13      17.75
# 25      16.80
# 37      17.94
# 49      22.11
# 61      20.48
# 73      19.01
# 85      20.09
# 97      14.78
# 109     18.57
# 121     19.09
# 133     22.18
# 145     16.06
# 157     12.01
# 169     29.37
# 181     29.61
# 193     20.72
# 205     35.83
# 217     34.69
# 229     48.15
# 241     61.63
# 253     59.28
# 265     95.39
# 277     39.09
# 289     76.39
# 301     88.58
# 313    102.20
# 325     95.31
# 337    100.82
# 349     50.58
# 361     30.32
# 373     53.47
# 385     62.23
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 41.39363636363637
# *******
# For month 3
# 2       12.61
# 14      18.30
# 26      16.20
# 38      19.48
# 50      20.39
# 62      19.90
# 74      18.92
# 86      20.32
# 98      14.68
# 110     18.54
# 122     21.33
# 134     20.97
# 146     15.12
# 158     14.68
# 170     29.84
# 182     27.25
# 194     24.53
# 206     33.51
# 218     36.74
# 230     54.19
# 242     62.69
# 254     60.44
# 266    105.45
# 278     47.94
# 290     81.20
# 302    102.86
# 314    106.16
# 326     92.94
# 338    100.80
# 350     47.82
# 362     37.55
# 374     49.33
# 386     62.73
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 42.89121212121212
# *******
# For month 4
# 3       12.84
# 15      18.68
# 27      17.86
# 39      21.07
# 51      18.43
# 63      20.83
# 75      20.23
# 87      20.25
# 99      16.42
# 111     19.90
# 123     23.50
# 135     19.70
# 147     15.35
# 159     17.31
# 171     25.72
# 183     27.49
# 195     26.18
# 207     28.17
# 219     36.75
# 231     52.98
# 243     69.44
# 255     63.98
# 267    112.58
# 279     49.65
# 291     84.29
# 303    109.53
# 315    103.32
# 327     92.02
# 339    102.07
# 351     54.45
# 363     40.75
# 375     51.06
# 387     66.25
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 44.21363636363637
# *******
# For month 5
# 4       15.38
# 16      19.44
# 28      17.42
# 40      20.12
# 52      18.20
# 64      21.23
# 76      20.98
# 88      19.95
# 100     17.89
# 112     19.74
# 124     21.17
# 136     20.82
# 148     14.91
# 160     17.72
# 172     28.79
# 184     28.63
# 196     27.04
# 208     28.11
# 220     40.28
# 232     49.83
# 244     70.84
# 256     63.46
# 268    125.40
# 280     59.03
# 292     73.74
# 304    100.90
# 316     94.66
# 328     94.51
# 340    102.18
# 352     59.27
# 364     46.71
# 376     48.48
# 388     69.98
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 44.75181818181818
# *******
# For month 6
# 5       13.43
# 17      20.07
# 29      16.53
# 41      20.05
# 53      16.70
# 65      20.19
# 77      22.39
# 89      19.09
# 101     19.06
# 113     18.45
# 125     20.42
# 137     19.26
# 149     13.72
# 161     17.92
# 173     31.82
# 185     27.60
# 197     25.52
# 209     30.66
# 221     38.03
# 233     56.35
# 245     70.95
# 257     67.49
# 269    133.88
# 281     69.64
# 293     75.34
# 305     96.26
# 317     82.30
# 329     95.77
# 341    105.79
# 353     59.82
# 365     48.76
# 377     45.18
# 389     67.87
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 45.03969696969697
# *******
# For month 7
# 6       11.59
# 18      21.34
# 30      15.50
# 42      19.78
# 54      18.45
# 66      21.40
# 78      21.78
# 90      17.89
# 102     19.66
# 114     17.33
# 126     21.30
# 138     19.66
# 150     14.17
# 162     20.10
# 174     29.70
# 186     26.43
# 198     26.97
# 210     30.76
# 222     40.78
# 234     59.00
# 246     74.41
# 258     74.12
# 270    133.37
# 282     64.15
# 294     76.32
# 306     97.30
# 318     87.90
# 330    104.67
# 342    103.59
# 354     50.90
# 366     44.65
# 378     46.63
# 390     70.98
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 45.53272727272727
# *******
# For month 8
# 7       15.10
# 19      20.31
# 31      15.52
# 43      18.58
# 55      27.31
# 67      21.69
# 79      21.34
# 91      18.01
# 103     18.38
# 115     18.02
# 127     21.90
# 139     19.95
# 151     13.47
# 163     21.28
# 175     31.26
# 187     27.37
# 199     28.39
# 211     31.57
# 223     44.90
# 235     64.99
# 247     73.04
# 259     72.36
# 271    116.67
# 283     71.05
# 295     76.60
# 307     86.33
# 319     94.13
# 331    106.57
# 343     96.54
# 355     42.87
# 367     44.72
# 379     48.04
# 391     68.06
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 45.343030303030304
# *******
# For month 9
# 8       14.87
# 20      19.53
# 32      14.54
# 44      19.59
# 56      33.51
# 68      21.89
# 80      21.88
# 92      17.50
# 104     17.45
# 116     18.23
# 128     23.97
# 140     19.80
# 152     15.03
# 164     23.80
# 176     33.88
# 188     26.20
# 200     29.66
# 212     28.31
# 224     45.94
# 236     65.59
# 248     63.80
# 260     79.92
# 272    104.11
# 284     69.41
# 296     75.24
# 308     85.52
# 320     94.51
# 332    106.29
# 344     93.21
# 356     45.48
# 368     45.18
# 380     49.82
# 392     70.23
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 45.269393939393936
# *******
# For month 10
# 9       14.90
# 21      19.86
# 33      13.77
# 45      20.10
# 57      36.04
# 69      23.23
# 81      21.69
# 93      18.15
# 105     17.72
# 117     17.43
# 129     24.88
# 141     21.33
# 153     14.46
# 165     22.69
# 177     33.11
# 189     22.17
# 201     28.84
# 213     30.34
# 225     53.28
# 237     62.26
# 249     58.89
# 261     85.80
# 273     76.61
# 285     75.72
# 297     81.89
# 309     86.32
# 321     89.49
# 333    100.54
# 345     84.40
# 357     46.22
# 369     49.78
# 381     51.58
# 393     70.75
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 44.67393939393939
# *******
# For month 11
# 10     15.22
# 22     18.85
# 34     14.14
# 46     19.86
# 58     32.33
# 70     22.46
# 82     20.34
# 94     16.61
# 106    18.07
# 118    17.99
# 130    23.71
# 142    20.19
# 154    13.00
# 166    25.00
# 178    34.42
# 190    19.64
# 202    26.35
# 214    31.11
# 226    48.47
# 238    58.32
# 250    59.08
# 262    94.77
# 274    57.31
# 286    77.99
# 298    84.25
# 310    97.16
# 322    86.53
# 334    93.86
# 346    75.79
# 358    42.44
# 370    45.66
# 382    56.64
# 394    56.96
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 43.167272727272724
# *******
# For month 12
# 11     16.11
# 23     17.28
# 35     16.38
# 47     21.10
# 59     27.28
# 71     19.50
# 83     19.41
# 95     14.52
# 107    17.16
# 119    19.03
# 131    25.23
# 143    18.33
# 155    11.35
# 167    26.10
# 179    28.44
# 191    19.39
# 203    29.46
# 215    32.13
# 227    43.15
# 239    59.41
# 251    61.96
# 263    91.69
# 275    41.12
# 287    74.47
# 299    89.15
# 311    98.56
# 323    87.86
# 335    97.63
# 347    59.29
# 359    37.19
# 371    51.97
# 383    57.88
# 395    49.52
# Name: Cushing, OK WTI Spot Price FOB (Dollars per Barrel), dtype: float64
# mean: 41.78939393939394
# {1: 41.703529411764706, 2: 41.39363636363637, 3: 42.89121212121212, 4: 44.21363636363637, 5: 44.75181818181818, 6: 45.03969696969697, 7: 45.53272727272727, 8: 45.343030303030304, 9: 45.269393939393936, 10: 44.67393939393939, 11: 43.167272727272724, 12: 41.78939393939394}
# *******
# For month 6
# 0      0.420
# 12     0.557
# 24     0.518
# 36     0.637
# 48     0.646
# 60     0.635
# 72     0.645
# 84     0.548
# 96     0.528
# 108    0.596
# 120    0.580
# 132    0.551
# 144    0.439
# 156    0.489
# 168    0.963
# 180    0.720
# 192    0.717
# 204    0.808
# 216    1.153
# 228    1.509
# 240    2.065
# 252    2.186
# 264    3.292
# 276    1.906
# 288    2.014
# 300    2.835
# 312    2.602
# 324    2.740
# 336    2.896
# 348    2.005
# 360    1.506
# 372    1.445
# 384    2.030
# Name: New York Harbor Conventional Gasoline Regular Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.3085151515151514
# *******
# For month 7
# 1      0.340
# 13     0.556
# 25     0.554
# 37     0.563
# 49     0.653
# 61     0.652
# 73     0.600
# 85     0.519
# 97     0.545
# 109    0.511
# 121    0.616
# 133    0.587
# 145    0.423
# 157    0.583
# 169    0.859
# 181    0.683
# 193    0.766
# 205    0.873
# 217    1.225
# 229    1.591
# 241    2.237
# 253    2.137
# 265    3.148
# 277    1.750
# 289    1.995
# 301    3.021
# 313    2.747
# 325    2.924
# 337    2.802
# 349    1.860
# 361    1.354
# 373    1.562
# 385    2.074
# Name: New York Harbor Conventional Gasoline Regular Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.3124242424242425
# *******
# For month 8
# 2      0.426
# 14     0.523
# 26     0.483
# 38     0.527
# 50     0.897
# 62     0.697
# 74     0.621
# 86     0.532
# 98     0.555
# 110    0.533
# 122    0.609
# 134    0.705
# 146    0.403
# 158    0.639
# 170    0.872
# 182    0.776
# 194    0.769
# 206    1.007
# 218    1.206
# 230    1.937
# 242    2.038
# 254    2.004
# 266    2.897
# 278    1.930
# 290    1.943
# 302    2.835
# 314    3.022
# 326    2.933
# 338    2.705
# 350    1.620
# 362    1.379
# 374    1.688
# 386    2.077
# Name: New York Harbor Conventional Gasoline Regular Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1
spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.358625
# {6: 1.3085151515151514, 7: 1.3124242424242425, 8: 1.3269090909090908, 9: 1.319909090909091, 10: 1.2586060606060605, 11: 1.206, 12: 1.1526060606060604, 1: 1.1776666666666666, 2: 1.1955, 3: 1.2576874999999998, 4: 1.3384687499999999, 5: 1.358625}
# *******
# For month 6
# 0      1.072
# 12     1.457
# 24     1.745
# 36     2.401
# 48     2.354
# 60     3.694
# 72     2.085
# 84     2.255
# 96     2.861
# 108    2.626
# 120    3.021
# 132    3.116
# 144    2.187
# 156    1.642
# 168    1.619
# 180    2.136
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 2.2669375
# *******
# For month 7
# 1      0.965
# 13     1.467
# 25     1.882
# 37     2.488
# 49     2.311
# 61     3.286
# 73     1.913
# 85     2.281
# 97     2.948
# 109    2.819
# 121    3.047
# 133    2.908
# 145    2.663
# 157    1.412
# 169    1.669
# 181    2.140
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 2.2624375
# *******
# For month 8
# 2      1.315
# 14     1.388
# 26     2.142
# 38     2.190
# 50     2.049
# 62     3.072
# 74     2.113
# 86     2.178
# 98     2.839
# 110    3.129
# 122    2.825
# 134    2.808
# 146    2.075
# 158    1.388
# 170    1.807
# 182    2.078
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 2.21225
# *******
# For month 9
# 3      0.949
# 15     1.481
# 27     2.278
# 39     1.782
# 51     2.208
# 63     2.870
# 75     2.056
# 87     2.069
# 99     2.917
# 111    3.162
# 123    2.907
# 135    2.719
# 147    1.715
# 159    1.552
# 171    1.823
# 183    2.224
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 2.1695
# *******
# For month 10
# 4      0.996
# 16     1.642
# 28     1.902
# 40     1.686
# 52     2.394
# 64     2.125
# 76     2.032
# 88     2.259
# 100    2.949
# 112    3.135
# 124    2.761
# 136    2.338
# 148    1.669
# 160    1.619
# 172    1.761
# 184    2.254
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 2.095125
# *******
# For month 11
# 5      1.020
# 17     1.404
# 29     1.577
# 41     1.797
# 53     2.559
# 65     1.268
# 77     1.979
# 89     2.245
# 101    2.737
# 113    2.792
# 125    2.651
# 137    2.024
# 149    1.507
# 161    1.434
# 173    1.836
# 185    1.739
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.9105625
# *******
# For month 12
# 6      0.959
# 18     1.185
# 30     1.606
# 42     1.805
# 54     2.450
# 66     1.110
# 78     2.014
# 90     2.420
# 102    2.702
# 114    2.615
# 126    2.685
# 138    1.508
# 150    1.647
# 162    1.500
# 174    1.646
# 186    1.597
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.8405625
# *******
# For month 1
# 7      1.079
# 19     1.379
# 31     1.873
# 43     1.682
# 55     2.323
# 67     1.457
# 79     2.057
# 91     2.447
# 103    2.920
# 115    2.900
# 127    2.628
# 139    1.301
# 151    1.320
# 163    1.612
# 175    1.944
# 187    1.607
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.9080624999999998
# *******
# For month 2
# 8      1.344
# 20     1.545
# 32     1.730
# 44     2.019
# 56     2.609
# 68     1.547
# 80     2.073
# 92     2.758
# 104    3.302
# 116    3.332
# 128    2.869
# 140    1.942
# 152    0.970
# 164    1.756
# 176    1.877
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 2.111533333333333
# *******
# For month 3
# 9      1.323
# 21     1.718
# 33     2.000
# 45     2.373
# 57     2.783
# 69     1.473
# 81     2.257
# 93     3.153
# 105    3.383
# 117    3.029
# 129    2.894
# 141    2.017
# 153    1.528
# 165    1.720
# 177    2.080
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 2.248733333333333
# *******
# For month 4
# 10     1.426
# 22     1.829
# 34     2.448
# 46     2.531
# 58     3.068
# 70     1.575
# 82     2.307
# 94     3.373
# 106    3.250
# 118    2.906
# 130    3.169
# 142    2.154
# 154    1.551
# 166    1.777
# 178    2.213
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 2.3718
# *******
# For month 5
# 11     1.649
# 23     1.600
# 35     2.551
# 47     2.572
# 59     3.311
# 71     1.847
# 83     2.115
# 95     3.055
# 107    3.234
# 119    2.999
# 131    3.036
# 143    2.472
# 155    1.530
# 167    1.746
# 179    2.295
# Name: Los Angeles Reformulated RBOB Regular Gasoline Spot Price (Dollars per Gallon), dtype: float64
# mean: 2.4008
# {6: 2.2669375, 7: 2.2624375, 8: 2.21225, 9: 2.1695, 10: 2.095125, 11: 1.9105625, 12: 1.8405625, 1: 1.9080624999999998, 2: 2.111533333333333, 3: 2.248733333333333, 4: 2.3718, 5: 2.4008}
# *******
# For month 6
# 0      0.380
# 12     0.523
# 24     0.448
# 36     0.485
# 48     0.481
# 60     0.535
# 72     0.612
# 84     0.525
# 96     0.492
# 108    0.476
# 120    0.514
# 132    0.522
# 144    0.378
# 156    0.433
# 168    0.782
# 180    0.756
# 192    0.646
# 204    0.759
# 216    0.994
# 228    1.612
# 240    1.925
# 252    1.991
# 264    3.801
# 276    1.747
# 288    2.032
# 300    2.967
# 312    2.619
# 324    2.752
# 336    2.882
# 348    1.762
# 360    1.416
# 372    1.332
# 384    2.112
# Name: New York Harbor No. 2 Heating Oil Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.2633636363636365
# *******
# For month 7
# 1      0.334
# 13     0.547
# 25     0.427
# 37     0.493
# 49     0.531
# 61     0.577
# 73     0.603
# 85     0.498
# 97     0.499
# 109    0.465
# 121    0.555
# 133    0.530
# 145    0.362
# 157    0.500
# 169    0.781
# 181    0.698
# 193    0.679
# 205    0.786
# 217    1.090
# 229    1.640
# 241    1.935
# 253    2.072
# 265    3.759
# 277    1.628
# 289    1.979
# 301    3.068
# 313    2.813
# 325    2.885
# 337    2.776
# 349    1.557
# 361    1.292
# 373    1.423
# 385    2.108
# Name: New York Harbor No. 2 Heating Oil Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1
spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.292
# {6: 1.2633636363636365, 7: 1.2693939393939393, 8: 1.2886363636363636, 9: 1.307030303030303, 10: 1.31, 11: 1.281, 12: 1.2468181818181816, 1: 1.2636969696969698, 2: 1.25565625, 3: 1.26828125, 4: 1.29384375, 5: 1.292}
# *******
# For month 4
# 0      0.000
# 12     0.000
# 24     0.000
# 36     0.000
# 48     0.000
# 60     0.000
# 72     0.000
# 84     0.000
# 96     0.000
# 108    0.000
# 120    0.000
# 132    2.053
# 144    3.443
# 156    1.449
# 168    2.284
# 180    3.271
# 192    3.242
# 204    2.900
# 216    2.958
# 228    1.843
# 240    1.247
# 252    1.586
# 264    2.079
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.2328260869565217
# *******
# For month 5
# 1      0.000
# 13     0.000
# 25     0.000
# 37     0.000
# 49     0.000
# 61     0.000
# 73     0.000
# 85     0.000
# 97     0.000
# 109    0.000
# 121    0.000
# 133    2.044
# 145    3.821
# 157    1.520
# 169    2.136
# 181    3.035
# 193    2.987
# 205    2.888
# 217    2.936
# 229    1.965
# 241    1.423
# 253    1.514
# 265    2.230
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.2390869565217393
# *******
# For month 6
# 2      0.000
# 14     0.000
# 26     0.000
# 38     0.000
# 50     0.000
# 62     0.000
# 74     0.000
# 86     0.000
# 98     0.000
# 110    0.000
# 122    2.091
# 134    2.120
# 146    3.887
# 158    1.820
# 170    2.108
# 182    3.054
# 194    2.710
# 206    2.891
# 218    2.962
# 230    1.888
# 242    1.491
# 254    1.417
# 266    2.146
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.3297826086956521
# *******
# For month 7
# 3      0.000
# 15     0.000
# 27     0.000
# 39     0.000
# 51     0.000
# 63     0.000
# 75     0.000
# 87     0.000
# 99     0.000
# 111    0.000
# 123    2.217
# 135    2.146
# 147    3.845
# 159    1.722
# 171    2.066
# 183    3.170
# 195    2.921
# 207    3.018
# 219    2.879
# 231    1.684
# 243    1.370
# 255    1.521
# 267    2.140
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.3347391304347829
# *******
# For month 8
# 4      0.000
# 16     0.000
# 28     0.000
# 40     0.000
# 52     0.000
# 64     0.000
# 76     0.000
# 88     0.000
# 100    0.000
# 112    0.000
# 124    2.247
# 136    2.106
# 148    3.273
# 160    1.927
# 172    2.122
# 184    3.010
# 196    3.179
# 208    3.068
# 220    2.850
# 232    1.516
# 244    1.399
# 256    1.631
# 268    2.153
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.3252608695652175
# *******
# For month 9
# 5      0.000
# 17     0.000
# 29     0.000
# 41     0.000
# 53     0.000
# 65     0.000
# 77     0.000
# 89     0.000
# 101    0.000
# 113    0.000
# 125    1.810
# 137    2.320
# 149    3.041
# 161    1.795
# 173    2.175
# 185    2.980
# 197    3.229
# 209    3.048
# 221    2.740
# 233    1.516
# 245    1.418
# 257    1.791
# 269    2.252
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.3093478260869562
# *******
# For month 10
# 6      0.000
# 18     0.000
# 30     0.000
# 42     0.000
# 54     0.000
# 66     0.000
# 78     0.000
# 90     0.000
# 102    0.000
# 114    0.000
# 126    1.794
# 138    2.417
# 150    2.397
# 162    1.982
# 174    2.301
# 186    3.008
# 198    3.236
# 210    2.995
# 222    2.532
# 234    1.472
# 246    1.559
# 258    1.799
# 270    2.332
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.296695652173913
# *******
# For month 11
# 7      0.000
# 19     0.000
# 31     0.000
# 43     0.000
# 55     0.000
# 67     0.000
# 79     0.000
# 91     0.000
# 103    0.000
# 115    0.000
# 127    1.811
# 139    2.700
# 151    1.923
# 163    1.998
# 175    2.377
# 187    3.095
# 199    3.180
# 211    2.938
# 223    2.430
# 235    1.413
# 247    1.463
# 259    1.916
# 271    2.048
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.2735652173913043
# *******
# For month 12
# 8      0.000
# 20     0.000
# 32     0.000
# 44     0.000
# 56     0.000
# 68     0.000
# 80     0.000
# 92     0.000
# 104    0.000
# 116    0.000
# 128    1.833
# 140    2.631
# 152    1.436
# 164    1.980
# 176    2.500
# 188    2.937
# 200    3.070
# 212    3.045
# 224    2.034
# 236    1.138
# 248    1.642
# 260    1.944
# 272    1.801
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.2169999999999999
# *******
# For month 1
# 9      0.000
# 21     0.000
# 33     0.000
# 45     0.000
# 57     0.000
# 69     0.000
# 81     0.000
# 93     0.000
# 105    0.000
# 117    0.000
# 129    1.630
# 141    2.590
# 153    1.496
# 165    2.066
# 177    2.642
# 189    3.080
# 201    3.103
# 213    3.117
# 225    1.678
# 237    0.979
# 249    1.623
# 261    2.074
# 273    1.846
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.2140869565217394
# *******
# For month 2
# 10     0.000
# 22     0.000
# 34     0.000
# 46     0.000
# 58     0.000
# 70     0.000
# 82     0.000
# 94     0.000
# 106    0.000
# 118    0.000
# 130    1.759
# 142    2.774
# 154    1.306
# 166    2.035
# 178    2.840
# 190    3.223
# 202    3.237
# 214    3.227
# 226    1.991
# 238    1.036
# 250    1.624
# 262    1.937
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.2267727272727273
# *******
# For month 3
# 11     0.000
# 23     0.000
# 35     0.000
# 47     0.000
# 59     0.000
# 71     0.000
# 83     0.000
# 95     0.000
# 107    0.000
# 119    0.000
# 131    1.891
# 143    3.253
# 155    1.338
# 167    2.159
# 179    3.131
# 191    3.302
# 203    3.037
# 215    2.993
# 227    1.856
# 239    1.190
# 251    1.528
# 263    1.930
# Name: New York Harbor Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon), dtype: float64
# mean: 1.254909090909091
# {4: 1.2328260869565217, 5: 1.2390869565217393, 6: 1.3297826086956521, 7: 1.3347391304347829, 8: 1.3252608695652175, 9: 1.3093478260869562, 10: 1.296695652173913, 11: 1.2735652173913043, 12: 1.2169999999999999, 1: 1.2140869565217394, 2: 1.2267727272727273, 3: 1.254909090909091}
# *******
# For month 4
# 0      0.540
# 12     0.552
# 24     0.543
# 36     0.551
# 48     0.469
# 60     0.500
# 72     0.617
# 84     0.541
# 96     0.426
# 108    0.430
# 120    0.719
# 132    0.770
# 144    0.669
# 156    0.743
# 168    0.973
# 180    1.573
# 192    2.074
# 204    2.036
# 216    3.365
# 228    1.369
# 240    2.243
# 252    3.267
# 264    3.226
# 276    2.808
# 288    2.888
# 300    1.702
# 312    1.147
# 324    1.510
# 336    2.015
# Name: U.S. Gulf Coast Kerosene-Type Jet Fuel Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.3884827586206894
# *******
# For month 5
# 1      0.515
# 13     0.569
# 25     0.579
# 37     0.553
# 49     0.472
# 61     0.511
# 73     0.557
# 85     0.549
# 97     0.416
# 109    0.415
# 121    0.762
# 133    0.821
# 145    0.666
# 157    0.714
# 169    1.092
# 181    1.471
# 193    2.070
# 205    2.044
# 217    3.738
# 229    1.488
# 241    2.063
# 253    3.085
# 265    2.974
# 277    2.725
# 289    2.868
# 301    1.849
# 313    1.299
# 325    1.412
# 337    2.155
# Name: U.S. Gulf Coast Kerosene-Type Jet Fuel Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.394206896551724
# *******
# For month 6
# 2      0.494
# 14     0.547
# 26     0.615
# 38     0.526
# 50     0.493
# 62     0.478
# 74     0.516
# 86     0.523
# 98     0.389
# 110    0.440
# 122    0.785
# 134    0.767
# 146    0.653
# 158    0.748
# 170    1.032
# 182    1.654
# 194    2.081
# 206    2.099
# 218    3.878
# 230    1.805
# 242    2.058
# 254    3.046
# 266    2.678
# 278    2.769
# 290    2.883
# 302    1.732
# 314    1.382
# 326    1.295
# 338    2.090
# Name: U.S. Gulf Coast Kerosene-Type Jet Fuel Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.3950344827586207
# *******
# For month 7
# 3      0.535
# 15     0.586
# 27     0.611
# 39     0.494
# 51     0.509
# 63     0.467
# 75     0.556
# 87     0.536
# 99     0.386
# 111    0.512
# 123    0.796
# 135    0.711
# 147    0.691
# 159    0.780
# 171    1.145
# 183    1.665
# 195    2.154
# 207    2.137
# 219    3.886
# 231    1.712
# 243    2.019
# 255    3.131
# 267    2.892
# 279    2.894
# 291    2.817
# 303    1.549
# 315    1.272
# 327    1.417
# 339    2.098
# Name: U.S. Gulf Coast Kerosene-Type Jet Fuel Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1
.S. Gulf Coast Kerosene-Type Jet Fuel Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.3523103448275862
# *******
# For month 2
# 10     0.637
# 22     0.543
# 34     0.553
# 46     0.501
# 58     0.467
# 70     0.557
# 82     0.619
# 94     0.449
# 106    0.309
# 118    0.780
# 130    0.815
# 142    0.551
# 154    1.055
# 166    0.933
# 178    1.334
# 190    1.754
# 202    1.740
# 214    2.728
# 226    1.259
# 238    1.989
# 250    2.839
# 262    3.207
# 274    3.218
# 286    2.965
# 298    1.766
# 310    0.973
# 322    1.547
# 334    1.849
# Name: U.S. Gulf Coast Kerosene-Type Jet Fuel Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.354892857142857
# *******
# For month 3
# 11     0.558
# 23     0.514
# 35     0.558
# 47     0.451
# 59     0.449
# 71     0.586
# 83     0.557
# 95     0.413
# 107    0.378
# 119    0.771
# 131    0.748
# 143    0.630
# 155    0.893
# 167    0.947
# 179    1.562
# 191    1.875
# 203    1.846
# 215    3.124
# 227    1.268
# 239    2.108
# 251    3.125
# 263    3.256
# 275    2.969
# 287    2.890
# 299    1.629
# 311    1.069
# 323    1.445
# 335    1.858
# Name: U.S. Gulf Coast Kerosene-Type Jet Fuel Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 1.3741785714285712
# {4: 1.3884827586206894, 5: 1.394206896551724, 6: 1.3950344827586207, 7: 1.412344827586207, 8: 1.4397241379310346, 9: 1.4748275862068967, 10: 1.4580000000000002, 11: 1.3894482758620688, 12: 1.3254137931034482, 1: 1.3523103448275862, 2: 1.354892857142857, 3: 1.3741785714285712}
# *******
# For month 6
# 0      0.344
# 12     0.328
# 24     0.288
# 36     0.318
# 48     0.348
# 60     0.344
# 72     0.245
# 84     0.309
# 96     0.555
# 108    0.431
# 120    0.375
# 132    0.559
# 144    0.670
# 156    0.818
# 168    1.097
# 180    1.139
# 192    1.813
# 204    0.846
# 216    1.037
# 228    1.520
# 240    0.788
# 252    0.863
# 264    1.046
# 276    0.369
# 288    0.507
# 300    0.590
# 312    0.880
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.6824814814814816
# *******
# For month 7
# 1      0.342
# 13     0.314
# 25     0.292
# 37     0.308
# 49     0.356
# 61     0.348
# 73     0.246
# 85     0.372
# 97     0.551
# 109    0.390
# 121    0.372
# 133    0.530
# 145    0.741
# 157    0.845
# 169    1.165
# 181    1.190
# 193    1.862
# 205    0.752
# 217    1.010
# 229    1.528
# 241    0.874
# 253    0.920
# 265    1.036
# 277    0.409
# 289    0.478
# 301    0.647
# 313    0.938
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.6968888888888889
# *******
# For month 8
# 2      0.354
# 14     0.305
# 26     0.300
# 38     0.313
# 50     0.384
# 62     0.369
# 74     0.241
# 86     0.406
# 98     0.583
# 110    0.415
# 122    0.415
# 134    0.548
# 146    0.837
# 158    0.941
# 170    1.138
# 182    1.186
# 194    1.651
# 206    0.906
# 218    1.072
# 230    1.528
# 242    0.901
# 254    1.061
# 266    1.018
# 278    0.374
# 290    0.449
# 302    0.758
# 314    0.974
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.7195185185185187
# *******
# For month 9
# 3      0.375
# 15     0.299
# 27     0.299
# 39     0.313
# 51     0.470
# 63     0.387
# 75     0.249
# 87     0.432
# 99     0.643
# 111    0.421
# 123    0.471
# 135    0.519
# 147    0.802
# 159    1.130
# 171    1.012
# 183    1.295
# 195    1.530
# 207    0.946
# 219    1.132
# 231    1.560
# 243    0.910
# 255    1.107
# 267    1.062
# 279    0.453
# 291    0.495
# 303    0.883
# 315    1.057
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.750074074074074
# *******
# For month 10
# 4      0.354
# 16     0.293
# 28     0.324
# 40     0.309
# 52     0.513
# 64     0.398
# 76     0.257
# 88     0.454
# 100    0.620
# 112    0.395
# 124    0.479
# 136    0.553
# 148    0.906
# 160    1.137
# 172    0.938
# 184    1.432
# 196    1.045
# 208    1.008
# 220    1.234
# 232    1.472
# 244    0.962
# 256    1.136
# 268    0.936
# 280    0.451
# 292    0.573
# 304    0.934
# 316    0.959
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.7434074074074075
# *******
# For month 11
# 5      0.327
# 17     0.275
# 29     0.344
# 41     0.310
# 53     0.583
# 65     0.360
# 77     0.248
# 89     0.436
# 101    0.608
# 113    0.331
# 125    0.472
# 137    0.547
# 149    0.863
# 161    0.999
# 173    0.954
# 185    1.556
# 197    0.738
# 209    1.076
# 221    1.254
# 233    1.458
# 245    0.890
# 257    1.181
# 269    0.802
# 281    0.430
# 293    0.538
# 305    0.980
# 317    0.745
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.7150000000000001
# *******
# For month 12
# 6      0.312
# 18     0.245
# 30     0.333
# 42     0.354
# 54     0.608
# 66     0.336
# 78     0.209
# 90     0.428
# 102    0.775
# 114    0.301
# 126    0.523
# 138    0.628
# 150    0.774
# 162    1.056
# 174    0.966
# 186    1.529
# 198    0.610
# 210    1.190
# 222    1.296
# 234    1.395
# 246    0.797
# 258    1.275
# 270    0.558
# 282    0.387
# 294    0.637
# 306    0.957
# 318    0.677
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.7094814814814815
# *******
# For month 1
# 7      0.337
# 19     0.263
# 31     0.327
# 43     0.354
# 55     0.474
# 67     0.302
# 79     0.217
# 91     0.555
# 103    0.774
# 115    0.291
# 127    0.606
# 139    0.745
# 151    0.737
# 163    0.989
# 175    0.893
# 187    1.506
# 199    0.727
# 211    1.312
# 223    1.348
# 235    1.294
# 247    0.838
# 259    1.395
# 271    0.478
# 283    0.336
# 295    0.747
# 307    0.904
# 319    0.665
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.7190370370370369
# *******
# For month 2
# 8      0.330
# 20     0.290
# 32     0.316
# 44     0.390
# 56     0.386
# 68     0.298
# 80     0.224
# 92     0.596
# 104    0.593
# 116    0.313
# 128    0.775
# 140    0.704
# 152    0.758
# 164    0.919
# 176    0.975
# 188    1.425
# 200    0.659
# 212    1.284
# 224    1.379
# 236    1.220
# 248    0.862
# 260    1.443
# 272    0.573
# 284    0.375
# 296    0.768
# 308    0.827
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.7185384615384616
# *******
# For month 3
# 9      0.342
# 21     0.284
# 33     0.327
# 45     0.369
# 57     0.385
# 69     0.275
# 81     0.242
# 93     0.512
# 105    0.558
# 117    0.380
# 129    0.623
# 141    0.585
# 153    0.878
# 165    0.926
# 177    1.037
# 189    1.475
# 201    0.653
# 213    1.136
# 225    1.397
# 237    1.261
# 249    0.895
# 261    1.064
# 273    0.542
# 285    0.452
# 297    0.615
# 309    0.788
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.6923461538461537
# *******
# For month 4
# 10     0.344
# 22     0.289
# 34     0.323
# 46     0.356
# 58     0.349
# 70     0.291
# 82     0.282
# 94     0.469
# 106    0.547
# 118    0.415
# 130    0.504
# 142    0.607
# 154    0.854
# 166    1.016
# 178    1.108
# 190    1.590
# 202    0.638
# 214    1.137
# 226    1.454
# 238    1.196
# 250    0.939
# 262    1.101
# 274    0.548
# 286    0.457
# 298    0.651
# 310    0.821
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.7033076923076924
# *******
# For month 5
# 11     0.328
# 23     0.296
# 35     0.327
# 47     0.348
# 59     0.353
# 71     0.274
# 83     0.283
# 95     0.512
# 107    0.513
# 119    0.406
# 131    0.541
# 143    0.677
# 155    0.797
# 167    1.041
# 179    1.149
# 191    1.700
# 203    0.701
# 215    1.082
# 227    1.521
# 239    0.954
# 251    0.932
# 263    1.043
# 275    0.470
# 287    0.516
# 299    0.640
# 311    0.917
# Name: Mont Belvieu, TX Propane Spot Price FOB (Dollars per Gallon), dtype: float64
# mean: 0.7046538461538462
# {6: 0.6824814814814816, 7: 0.6968888888888889, 8: 0.7195185185185187, 9: 0.750074074074074, 10: 0.7434074074074075, 11: 0.7150000000000001, 12: 0.7094814814814815, 1: 0.7190370370370369, 2: 0.7185384615384616, 3: 0.6923461538461537, 4: 0.7033076923076924, 5: 0.7046538461538462}
# c:\users\kaush\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:126: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#  Evaluation Staistics:
#
#  ***Random Forest Regressor***
# R-Square Value: 0.9688631103470305
# Mean Squared Error 23.99028457198338
# Explained Variance Score 0.9707588111414488
# Mean Absolute Error 3.350356249999811
# Median Absolute Error 1.6815799999997267
#
#  ***Decision Tree Regressor***
# R-Square Value: 0.8984063970565326
# Mean Squared Error 78.27562330312693
# Explained Variance Score 0.8988861135499653
# Mean Absolute Error 5.6834995777878605
# Median Absolute Error 3.4609444444444435
#
#  ***Linear Regression Model***
# R-Square Value: 0.546764051077779
# Mean Squared Error 349.2082707708741
# Explained Variance Score 0.5480570633369557
# Mean Absolute Error 15.777377677815958
# Median Absolute Error 13.804717735262837
# Yearly Change in Price is stored in file named: output.xlsx
# Monthly Change in Price is stored in file named: output_m.xlsx
# The resultant Predicted Values are stored in a File named: testResults.csv

# %%
# 6.Identify the correlation between Conventional Gasoline prices between New York Harbor and U.S. Gulf Coast
x1.corr(method='pearson', min_periods=1)
# Out:
#                   Change(New York)  Change(U.S)
# Change(New York)          1.000000     0.952569
# Change(U.S)               0.952569     1.000000

# %% [markdown]
# #7.Is there a month/quarter/year where prices of all Products were lower than prior data points
#
# Yes there are some month/quarter/year where price of all products is lower than prior points, because when i calculated the change between the price there are negative values in the chnage, which directely shows the lower value of the prices than prior data points. have a look at the cange column in the above calculated dataset.
